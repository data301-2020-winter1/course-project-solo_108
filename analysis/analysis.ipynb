# %%
# import pandas as pd
import matplotlib.pyplot as plt
from analysis.project_functions import *
matched_df, players_df = load_and_process("../data/raw/matches_sample.json")
print(matched_df)
print(players_df)
# Out:
#       duration  first_blood_time  dire_kills  radiant_kills  radiant_win
# 0         1597               181        20.0           47.0         True
# 1         1965               217        32.0           32.0        False
# 2         1945                 0        53.0           28.0        False
# 3         1476                 0        11.0           41.0         True
# 4         1411                 0        12.0           35.0         True
# ...        ...               ...         ...            ...          ...
# 5759      2227               152         0.0            0.0        False
# 5760      3023                51         0.0            0.0         True
# 5761      2424               203         0.0            0.0         True
# 5762      2873               220         0.0            0.0        False
# 5763      2694               259         0.0            0.0         True
#
# [5764 rows x 5 columns]
#        hero_id  assists  kills  deaths  gpm  xpm    win
# ...

# %% [markdown]
# ## Duration Plot

# %%
plot = duration_plot(matched_df)
plot

# %% [markdown]
# ## First Blood Time Plot

# %%
plot = first_blood_time_plot(matched_df)
plot

# %% [markdown]
# ## Radiant Kills Plot

# %%
plot = radiant_kills_plot(matched_df)
plot

# %% [markdown]
# ## Winrate Plot
# Show the winrate of the 5 heroes with highest winrates

# %%
plot = winrate_plot(players_df)
plot
# Out:
# <AxesSubplot:xlabel='Hero id', ylabel='Average Win Rate'>

# %% [markdown]
# ## Kills Plot
# Show the Kills of the 5 heroes with highest Kills

# %%
plot = kills_plot(players_df)
plot
# Out:
# <AxesSubplot:xlabel='Hero id', ylabel='Average Number of Kills'>

# %% [markdown]
# ## Assists Plot
# Show the Assists of the 5 heroes with highest Kills

# %%
plot = assists_plot(players_df)
plot
# Out:
# <AxesSubplot:xlabel='Hero id', ylabel='Average Number of Assists'>

# %% [markdown]
# ## Death Plot
# Show the deaths of the 5 heroes with lowest deaths

# %%
plot = deaths_plot(players_df)
plot
# Out:
# <AxesSubplot:xlabel='Hero id', ylabel='Average Number of Deaths'>

# %% [markdown]
# ## Gold per Minute (GPM) Plot
# Show the GPM of the 5 heroes with highest GPM

# %%
plot = gpm_plot(players_df)
plot
# Out:
# <AxesSubplot:xlabel='Hero id', ylabel='Average Gold per Minute'>

# %% [markdown]
# ## Experience per Minute (XPM) Plot
# Show the XPM of the 5 heroes with highest XPM

# %%
plot = xpm_plot(players_df)
plot
# Out:
# <AxesSubplot:xlabel='Hero id', ylabel='Average Experience per Minute'>

# %% [markdown]
# # Conclusion
#
# ## Insights
# The first 3 graphs give us some insight about the game.
# These are just interesting to me they have no relation to
# the research question.
#
# ## Research Question
# We wanted to find our dream team in DOTA. What are the best
# combination of heroes? To answer that we first need to know
# what makes a team great. Heroes have different abilities and
# a team is good if they can have a lot of everything. As we
# have teams of five, I chose 5 attributes to determine the
# overall ability of a team.
#
# ### Attributes
# - Winrate
#     + Heroes with higher winrates have better chance of winning
#     the game.
#     + The winrate graph shows the top 5 heros with the highest
#     winrate
#     + Heroes
#         * Shadow Fiend
#         * Naga Siren
#         * Timbersaw
#         * Bristleback
#         * Techies
# - Kill Potential
#     + We want at least one hero with kill potential so it can
#     kill the enemy heroes in fights
#     + The kills graph shows the heroes with highest average kill
#     in the game, the more the number of kills the more the potential
#     a hero has for killing
#     + Heroes
#         * Storm Spirit
#         * Queen of Pain
#         * Phantom Assassin
#         * Clinkz
#         * Ursa
# - Support
#     + We want to have a hero in our team who can support other
#     heroes by assisting them. From my personal experience
#     team without a support usually suffer a lot in the game
#     and are more likely to lose.
#     + The number of assist shown in the assists graph in a good
#     indicator of supporting ability of a hero
#     + Heroes
#         * Axe
#         * Bounty Hunter
#         * Spirit Breaker
#         * IO
#         * Tusk
# - Durability
#     + We want at least one durable hero in our team so it can
#     be out front-liner or our initiator.
#     + The deaths graph shows the heroes with least deaths,
#     durable heroes are less likely to die, well because they are
#     durable.
#     + Heroes
#         * Anti-Mage
#         * Morphling
#         * Lifestealer
#         * Lone Druid
#         * Medusa
#     + This came as a suprise to me, because some of the heroes
#     in this section are not durable but they have escape mechanism,
#     which makes sense to me now but I didn't take this into account.
# - Resources
#     + Every team needs gold and experience. Usually there is one hero in the team
#     whose job is to farm in early stages of the game and get a lot
#     of gold so they can buy items and eventually become stronger
#     in the late game.
#     + This can be seen in the gpm and xpm graph
#     + Heroes
#         * Anti-Mage
#         * Templar Assassin
#         * Alchemist
#         * Meepo
#         * Terrorblade
#         * Broodmother
#         * Alchemist
#
# ### The Dream Team
# There are a lot more to take into account when we are choosing
# heroes, for example the lanes each hero goes to. But in the scope of this research we are limiting it
# to what we already calculated. Now I have to choose 5 heroes
# (one from each section) that from my experience I think it makes the best team.
#
# * Anti-Mage (SafeLane)
# * Medusa (MidLane)
# * Spirit Breaker (SoftSupport)
# * Techies (HardSupport)
# * Clinkz (OffLane)
#
# Boom! There is our dream team. Tbh, there are some issues
# with this team. But it has the potential. I have to try it
# in real games to see the if it actually works as I expected or
# not.
